# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/Gr_AOI_52.dat", sep="\s+",engine="python")

# %%
data.head()
# Out:
#                                                                                                                                                                                                                WS2  \
# VASEmethod[EllipsometerType=4,              Isotropic, FixedPol=45.00, ZoneAve=1, Revs=400, OffsetMode=2, Offset1=0.11742, Offset2=0.23822, Offset3=-0.019523, WVASE=3.802, HardVer=17.034, Wed Sep 18.0  17:07:16
# Original[s1_bulk_ws2_2d_semic_45deg_01.dat] NaN        NaN             NaN        NaN       NaN           NaN              NaN              NaN                NaN          NaN             NaN NaN NaN       None
# nm                                          NaN        NaN             NaN        NaN       NaN           NaN              NaN              NaN                NaN          NaN             NaN NaN NaN       None
# ...

# %%
# Out:
#                                                                                                                           WS2  \
# Original[s1_bulk_ws2_2d_semic_45deg_01.dat] NaN    NaN      NaN       NaN      NaN      NaN NaN NaN NaN NaN NaN NaN NaN  None
# 365.0                                       52.000 26.77394 194.63693 0.012792 0.017822 NaN NaN NaN NaN NaN NaN NaN NaN  None
# 370.0                                       52.000 28.26450 194.03227 0.007145 0.008860 NaN NaN NaN NaN NaN NaN NaN NaN  None
# 375.0                                       52.000 26.99553 194.12927 0.004430 0.006502 NaN NaN NaN NaN NaN NaN NaN NaN  None
# 380.0                                       52.000 26.53677 195.29250 0.003414 0.005042 NaN NaN NaN NaN NaN NaN NaN NaN  None
# ...                                                                                                                       ...
# ...

# %%
data = pd.read_csv("data/example_data.phi", sep="\s+",engine="python")

# %%
data.head()
# Out:
#        Angle       Delta        Psi
# 0  70.000000  168.172119  10.496649
# 1  70.200005  167.972336  10.145239
# 2  70.400032  167.734497   9.810260
# 3  70.600014  167.469971   9.465815
# 4  70.800018  167.192352   9.122969

# %%
data[1:3]
# Out:
#     Null-Elli winkelabh�ngig           / Einfallswinkel, Delta,   Psi   30.  \
# 1  70.0000000     168.172119  10.4966488            None   None  None  None
# 2  70.2000046     167.972336  10.1452389            None   None  None  None
#
#    Januar  2020  14:16:21
# 1     NaN   NaN       NaN
# 2     NaN   NaN       NaN

# %%
data['Angle']
# Out:
# 0     70.000000
# 1     70.200005
# 2     70.400032
# 3     70.600014
# 4     70.800018
# 5     71.000023
# 6     71.200028
# 7     71.400032
# 8     71.600037
# 9     71.800049
# 10    72.000053
# 11    72.200058
# 12    72.400063
# 13    72.600075
# 14    72.800072
# 15    73.000076
# 16    73.200081
# 17    73.400085
# 18    73.600090
# 19    73.800140
# 20    74.000099
# 21    74.200104
# 22    74.400108
# 23    74.600121
# 24    74.800125
# 25    75.000130
# 26    75.200089
# 27    75.400139
# 28    75.600143
# 29    75.800148
# 30    76.000191
# 31    76.200157
# 32    76.400177
# 33    76.600166
# 34    76.800163
# 35    77.000175
# 36    77.200188
# 37    77.400192
# 38    77.600243
# 39    77.800186
# 40    78.000191
# 41    78.200211
# 42    78.400215
# 43    78.600220
# 44    78.800224
# 45    79.000229
# 46    79.200233
# 47    79.400238
# 48    79.600243
# 49    79.800255
# 50    80.000267
# 51    80.000267
# Name: Angle, dtype: float64

# %%
import scipy.io
mat = scipy.io.loadmat('data/Glass_optical_constants.mat')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-8f08f9dfb417> in <module>
#       1 import scipy.io
# ----> 2 mat = scipy.io.loadmat('data/Glass_optical_constants.mat')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     221     variable_names = kwargs.pop('variable_names', None)
#     222     with _open_file_context(file_name, appendmat) as f:
# --> 223         MR, _ = mat_reader_factory(f, **kwargs)
#     224         matfile_dict = MR.get_variables(variable_names)
#     225
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/io/matlab/mio.py in mat_reader_factory(file_name, appendmat, **kwargs)
#      70     """
#      71     byte_stream, file_opened = _open_file(file_name, appendmat)
# ---> 72     mjv, mnv = get_matfile_version(byte_stream)
#      73     if mjv == 0:
# ...

# %%
import numpy as np
import h5py
f = h5py.File('data/Glass_optical_constants.mat','r')
data = f.get('data/variable1')
data = np.array(data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-cb19f7c51356> in <module>
#       1 import numpy as np
#       2 import h5py
# ----> 3 f = h5py.File('data/Glass_optical_constants.mat','r')
#       4 data = f.get('data/variable1')
#       5 data = np.array(data)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     404             with phil:
#     405                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
#     408                                swmr=swmr)
#
# ...

# %%
save('data/Glass_optical_constants.mat', '-v7')
# Out:
# '-v7)' was not found in history, as a file, url, nor in the user namespace.

# %%
data = pd.read_csv("data/Glass_optical_constants.mat")

# %%
data
# Out:
#                            ANGSTROMS
# 0                               E1E2
# 1    2500.0000\t2.6286785\t0.0000000
# 2    2510.0000\t2.6256799\t0.0000000
# 3    2520.0000\t2.6227186\t0.0000000
# 4    2530.0000\t2.6197940\t0.0000000
# ..                               ...
# 582  9350.0000\t2.2901251\t0.0000000
# 583  9375.0000\t2.2899911\t0.0000000
# 584  9400.0000\t2.2898581\t0.0000000
# 585  9425.0000\t2.2897262\t0.0000000
# 586  9450.0000\t2.2895953\t0.0000000
#
# [587 rows x 1 columns]
